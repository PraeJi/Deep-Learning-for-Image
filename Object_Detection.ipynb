# %% [markdown]
# <a href="https://colab.research.google.com/github/PraeJi/Deep-Learning-for-Image/blob/main/Object_Detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi
# Out:
# Thu Aug 22 01:28:45 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   47C    P8               9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %% [markdown]
# # Introduction object detection

# %% [markdown]
# ![1.png](data:image/png;base64,...)

# %% [markdown]
# ![2.png](data:image/png;base64,...)

# %% [markdown]
# ![3.png](data:image/png;base64,...)

# %% [markdown]
# # 1.Install Yolov5 From git

# %% [markdown]
# https://github.com/ultralytics/yolov5

# %%
import pandas as pd
import matplotlib.pyplot as plt
from PIL import Image,ImageDraw
from IPython import display

# %%
import torch

# %%
device = ("cuda" if torch.cuda.is_available() else "cpu")
device
# Out:
# 'cuda'

# %%
# !git clone https://github.com/ultralytics/yolov5.git
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 16858, done.
# remote: Counting objects: 100% (53/53), done.
# remote: Compressing objects: 100% (47/47), done.
# remote: Total 16858 (delta 19), reused 35 (delta 6), pack-reused 16805 (from 1)
# Receiving objects: 100% (16858/16858), 15.54 MiB | 9.20 MiB/s, done.
# Resolving deltas: 100% (11557/11557), done.

# %%
# !pwd
# Out:
# /content

# %%
# %cd yolov5
# Out:
# /content/yolov5

# %%
# !git clone https://git-ai.inet-th.net/suphanat.bo/kong_dataset_dogcat.git
# Out:
# Cloning into 'kong_dataset_dogcat'...
# remote: Enumerating objects: 11362, done.
# remote: Counting objects: 100% (21/21), done.
# remote: Compressing objects: 100% (12/12), done.
# remote: Total 11362 (delta 13), reused 9 (delta 9), pack-reused 11341 (from 1)
# Receiving objects: 100% (11362/11362), 265.99 MiB | 29.83 MiB/s, done.
# Resolving deltas: 100% (3813/3813), done.
# Updating files: 100% (11077/11077), done.

# %%
img = Image.open('').convert('RGB')
print(img.size)
print(imshow(img))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/PIL/Image.py in open(fp, mode, formats)
#    3230     try:
# -> 3231         fp.seek(0)
#    3232     except (AttributeError, io.UnsupportedOperation):
#
# AttributeError: 'str' object has no attribute 'seek'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-33e8f3f1bf87> in <cell line: 1>()
# ----> 1 img = Image.open('').convert('RGB')
#       2 print(img.size)
#       3 print(imshow(img))
#
# /usr/local/lib/python3.10/dist-packages/PIL/Image.py in open(fp, mode, formats)
#    3231         fp.seek(0)
#    3232     except (AttributeError, io.UnsupportedOperation):
# -> 3233         fp = io.BytesIO(fp.read())
#    3234         exclusive_fp = True
#    3235
#
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
df = pd.read_csv('')
df

# %%
df['label'].value_counts()

# %%
df['filename'][1]

# %%
i=0
path_img = ''

im = Image.open(path_img + df['filename'][i]).convert('RGB')
print(im.size)
print(df['label'][i])
plt.imshow(im)

# %%
i=0
path_img = ''
im = Image.open(path_img + df['filename'][i]).convert('RGB')
print(im.size)
print(df['label'][i])

draw = ImageDraw.Draw(im)
draw.ractangle((0,0,100,100),width=5,outline="red") #xmin,ymin,xmax,ymax
plt.imshow(im)

# %%
df['label'][100]

# %%
df[['xmin','ymin','xmax','ymax']].iloc[0]

# %% [markdown]
# # 2.Create dataset

# %% [markdown]
# #3.Prepare the directory
